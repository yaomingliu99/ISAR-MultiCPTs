# %% [markdown]
# ## CPT Linear Risk with PyMC
#
# ### Run the model under env: nutbold016

# %%
import importlib
from importlib.metadata import version as package_version
import nutbolt

NUTBOLT_VERSION = package_version("nutbolt")
assert NUTBOLT_VERSION.startswith("2027."), f"Expected nutbolt 2027.x, found {NUTBOLT_VERSION}"
print(f"Using nutbolt {NUTBOLT_VERSION} from {nutbolt.__file__}")

importlib.reload(nutbolt.meta)
importlib.reload(nutbolt.postprocess)
importlib.reload(nutbolt.sampling)
importlib.reload(nutbolt.model)
importlib.reload(nutbolt.sar_vars_sel_runner)
importlib.reload(nutbolt.sar_hlm_runner)
importlib.reload(nutbolt.benchkit)
# Out:
# Using nutbolt 2027.0.0 from /home/yliu/SAR Bayesian Model 2027/nutbolt_2027/src/nutbolt/__init__.py
# <module 'nutbolt.benchkit' from '/home/yliu/SAR Bayesian Model 2027/nutbolt_2027/src/nutbolt/benchkit.py'>

# %%
import pandas as pd
import os
import numpy as np
from pathlib import Path

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
from nutbolt import sar_cptlin_runner
from nutbolt.metadata import DEFAULT_METADATA, MetadataRegistry

# %%
data_folder = Path("/mnt/d/ISAR Multi-CPTs/Oct 2026/Data")
# Working folder
master_folder = Path("/mnt/d/ISAR Multi-CPTs/Oct 2026/Multiple CPTs")
master_folder.mkdir(parents=True, exist_ok=True)
os.chdir(master_folder)

# %%
df = pd.read_parquet(data_folder / "sar5yr_for_cptlin.parquet")

# %%
df.shape
# Out:
# (4907935, 80)

# %%
df.columns
# Out:
# Index(['division', 'asm1', 'prncptx', 'age', 'agegroup', 'agegroup_bucket',
#        'asaclas', 'fnstatpressurg', 'oprymd', 'tend', 'hdisdt', 'opsdlos',
#        'postcode', 'score1b', 'compssi', 'computi', 'compdvt', 'compvent',
#        'comprenal', 'comptube', 'compcard', 'comppneu', 'compsepsis',
#        'returnor', 'readmission', 'dsermorb', 'ssi', 'ssi2', 'cnscva',
#        'postopcdiff', 'dehis', 'colon', 'colorectal', 'sermorb', 'orgspcssi',
#        'wndinfd', 'dssipatos', 'sssipatos', 'ossipatos', 'concpt1', 'concpt2',
#        'concpt3', 'concpt4', 'concpt5', 'concpt6', 'concpt7', 'concpt8',
#        'concpt9', 'concpt10', 'othcpt1', 'othcpt2', 'othcpt3', 'othcpt4',
#        'othcpt5', 'othcpt6', 'othcpt7', 'othcpt8', 'othcpt9', 'othcpt10',
#        'scorepatos', 'asaclas_c', 't_procs', 'delirium', 'fhsdecline',
#        'los75colo', 'los75pandistal', 'los75panwhipple', 'los75gencole',
#        'los75genproc', 'los75hepmajor', 'los75heppartial', 'los75geneso',
#        'los75vascaaa', 'los75vascevar', 'los75vascaio', 'los75vascleo',
#        'los75nsgbrain', 'los75uroneph', 'los75urocys', 'los75tholung'],
#       dtype='str')

# %%
df.columns = df.columns.str.lower()

# %%
output_folder = master_folder

# %% [markdown]
# ## Start modeling for All cases Morbidity

# %%
model_name="Morbidity_pymc"
print(f"\n{"*"*40}\n{model_name}\n{"*"*40}\n")
sar_cptlin_runner.run_model(
    outcome="score1b",
    model_name=model_name,
    cluster_var="prncptx",
    df=df.copy(),
    predictors = ["agegroup_bucket", "asaclas", "fnstatpressurg"],
    target_accept=0.3,
    chains_per_run=4,
    n_total_chains=4,
    tune=1000,
    draws=3000,
    low_rank_modified_mass_matrix=True,
    tolerance=1000,
    check_every_s=20,
    max_time_s=3600, 
    seed=123,
    output_folder=output_folder)
# Out:
# ****************************************
# Morbidity_pymc
# ****************************************
#
# [NutBolt] Predictor missingness before filtering: none. Rows before=4907935, rows with any missing=0, after=4907935, dropped=0.
# [NutBolt] Model graph saved as Morbidity_pymc.png (dpi=1200)
# partial idata saved at /mnt/d/ISAR Multi-CPTs/Oct 2026/Multiple CPTs/Morbidity_pymc
#
# [NutBolt] Start nutpie run 1/10: have 0/4 complete chains.
# [NutBolt] Using seed = 127 for this run.
# <style>
#     :root {
#         --column-width-1: 40%; /* Progress column width */
#         --column-width-2: 15%; /* Chain column width */
#         --column-width-3: 15%; /* Divergences column width */
#         --column-width-4: 15%; /* Step Size column width */
#         --column-width-5: 15%; /* Gradients/Draw column width */
#     }
#
#     .nutpie {
#         max-width: 800px;
#         margin: 10px auto;
#         font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#         //color: #333;
#         //background-color: #fff;
#         padding: 10px;
#         box-shadow: 0 4px 6px rgba(0,0,0,0.1);
#         border-radius: 8px;
#         font-size: 14px; /* Smaller font size for a more compact look */
#     }
#     .nutpie table {
#         width: 100%;
#         border-collapse: collapse; /* Remove any extra space between borders */
#     }
#     .nutpie th, .nutpie td {
#         padding: 8px 10px; /* Reduce padding to make table more compact */
#         text-align: left;
#         border-bottom: 1px solid #888;
#     }
#     .nutpie th {
#         //background-color: #f0f0f0;
#     }
#
#     .nutpie th:nth-child(1) { width: var(--column-width-1); }
#     .nutpie th:nth-child(2) { width: var(--column-width-2); }
#     .nutpie th:nth-child(3) { width: var(--column-width-3); }
#     .nutpie th:nth-child(4) { width: var(--column-width-4); }
#     .nutpie th:nth-child(5) { width: var(--column-width-5); }
#
#     .nutpie progress {
#         width: 100%;
#         height: 15px; /* Smaller progress bars */
#         border-radius: 5px;
#     }
#     progress::-webkit-progress-bar {
#         background-color: #eee;
#         border-radius: 5px;
#     }
#     progress::-webkit-progress-value {
#         background-color: #5cb85c;
#         border-radius: 5px;
#     }
#     progress::-moz-progress-bar {
#         background-color: #5cb85c;
#         border-radius: 5px;
#     }
#     .nutpie .progress-cell {
#         width: 100%;
#     }
#
#     .nutpie p strong { font-size: 16px; font-weight: bold; }
#
#     @media (prefers-color-scheme: dark) {
#         .nutpie {
#             //color: #ddd;
#             //background-color: #1e1e1e;
#             box-shadow: 0 4px 6px rgba(0,0,0,0.2);
#         }
#         .nutpie table, .nutpie th, .nutpie td {
#             border-color: #555;
#             color: #ccc;
#         }
#         .nutpie th {
#             background-color: #2a2a2a;
#         }
#         .nutpie progress::-webkit-progress-bar {
#             background-color: #444;
#         }
#         .nutpie progress::-webkit-progress-value {
#             background-color: #3178c6;
#         }
#         .nutpie progress::-moz-progress-bar {
#             background-color: #3178c6;
#         }
#     }
# </style>
# <div class="nutpie">
#     <p><strong>Sampler Progress</strong></p>
#     <p>Total Chains: <span id="total-chains">4</span></p>
#     <p>Active Chains: <span id="active-chains">2</span></p>
#     <p>
#         Finished Chains:
#         <span id="active-chains">2</span>
#     </p>
#     <p>Sampling for 9 minutes</p>
#     <p>
#         Estimated Time to Completion:
#         <span id="eta">17 minutes</span>
#     </p>
#
#     <progress
#         id="total-progress-bar"
#         max="16000"
#         value="8167">
#     </progress>
#     <table>
#         <thead>
#             <tr>
#                 <th>Progress</th>
#                 <th>Draws</th>
#                 <th>Divergences</th>
#                 <th>Step Size</th>
#                 <th>Gradients/Draw</th>
#             </tr>
#         </thead>
#         <tbody id="chain-details">
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="4000"
#                             value="4000">
#                         </progress>
#                     </td>
#                     <td>4000</td>
#                     <td>2222</td>
#                     <td>0.34</td>
#                     <td>3</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="4000"
#                             value="79">
#                         </progress>
#                     </td>
#                     <td>79</td>
#                     <td>0</td>
#                     <td>0.00</td>
#                     <td>1023</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="4000"
#                             value="88">
#                         </progress>
#                     </td>
#                     <td>88</td>
#                     <td>0</td>
#                     <td>0.00</td>
#                     <td>1023</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="4000"
#                             value="4000">
#                         </progress>
#                     </td>
#                     <td>4000</td>
#                     <td>0</td>
#                     <td>0.48</td>
#                     <td>7</td>
#                 </tr>
#
#             </tr>
#         </tbody>
#     </table>
# </div>
# /home/yliu/miniforge3/envs/SAR_2027/lib/python3.13/site-packages/jax/_src/numpy/array_methods.py:126: UserWarning: Explicitly requested dtype float64 requested in astype is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/jax-ml/jax#current-gotchas for more.
#   return lax_numpy.astype(self, dtype, copy=copy, device=device)
# [NutBolt] Draws: {0: 23, 1: 6, 2: 14, 3: 19}; Grads/Draw: {0: [255, 31, 127, 255, 255], 1: [31, 31, 255, 255, 511], 2: [4, 63, 127, 255, 511], 3: [31, 127, 127, 255, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 25, 1: 8, 2: 17, 3: 84}; Grads/Draw: {0: [127, 255, 255, 1023, 1023], 1: [255, 255, 511, 1023, 1023], 2: [255, 511, 1023, 1023, 1023], 3: [31, 2, 3, 31, 4]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 28, 1: 11, 2: 23, 3: 261}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 1023, 1023], 2: [255, 63, 63, 127, 511], 3: [15, 15, 15, 15, 15]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 30, 1: 16, 2: 26, 3: 449}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 255, 63, 127, 511], 2: [127, 511, 1023, 1023, 1023], 3: [7, 7, 7, 7, 7]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 33, 1: 19, 2: 28, 3: 585}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [127, 511, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [7, 15, 15, 15, 15]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 35, 1: 21, 2: 31, 3: 680}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [15, 15, 15, 15, 15]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 38, 1: 24, 2: 34, 3: 722}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [15, 7, 15, 7, 15]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 145, 1: 27, 2: 36, 3: 799}; Grads/Draw: {0: [7, 15, 15, 3, 4], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [15, 15, 7, 15, 7]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 380, 1: 30, 2: 39, 3: 895}; Grads/Draw: {0: [5, 15, 15, 15, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [7, 15, 7, 7, 15]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 525, 1: 33, 2: 42, 3: 1118}; Grads/Draw: {0: [7, 7, 15, 7, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [7, 7, 7, 7, 7]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 620, 1: 35, 2: 45, 3: 1344}; Grads/Draw: {0: [7, 15, 15, 15, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [7, 15, 7, 7, 15]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 721, 1: 38, 2: 47, 3: 1567}; Grads/Draw: {0: [7, 15, 7, 7, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [15, 7, 7, 7, 15]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 779, 1: 41, 2: 50, 3: 1814}; Grads/Draw: {0: [15, 15, 7, 15, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [7, 15, 15, 7, 15]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 871, 1: 44, 2: 53, 3: 2048}; Grads/Draw: {0: [15, 15, 15, 6, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [15, 15, 7, 15, 15]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 1059, 1: 46, 2: 56, 3: 2248}; Grads/Draw: {0: [15, 7, 15, 13, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [7, 15, 15, 15, 7]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 1281, 1: 49, 2: 58, 3: 2451}; Grads/Draw: {0: [6, 15, 11, 11, 14], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [7, 15, 7, 7, 15]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 1515, 1: 51, 2: 61, 3: 2652}; Grads/Draw: {0: [6, 10, 11, 15, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [15, 7, 15, 7, 7]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 1745, 1: 54, 2: 63, 3: 2858}; Grads/Draw: {0: [15, 4, 9, 11, 5], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [7, 15, 15, 15, 7]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 1977, 1: 56, 2: 66, 3: 3064}; Grads/Draw: {0: [15, 7, 10, 5, 6], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [7, 7, 7, 7, 7]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 2203, 1: 59, 2: 68, 3: 3265}; Grads/Draw: {0: [15, 12, 15, 4, 7], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [7, 15, 15, 7, 7]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 2434, 1: 61, 2: 71, 3: 3471}; Grads/Draw: {0: [8, 5, 15, 15, 5], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [15, 15, 15, 15, 15]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 2677, 1: 64, 2: 73, 3: 3684}; Grads/Draw: {0: [15, 12, 6, 12, 6], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [15, 7, 7, 7, 7]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 2896, 1: 66, 2: 76, 3: 3885}; Grads/Draw: {0: [7, 6, 13, 9, 7], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [15, 7, 7, 7, 7]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 3143, 1: 69, 2: 78, 3: 4000}; Grads/Draw: {0: [5, 9, 15, 8, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [7, 7, 15, 7, 7]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 3450, 1: 72, 2: 82, 3: 4000}; Grads/Draw: {0: [3, 7, 11, 9, 6], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [7, 7, 15, 7, 7]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 3754, 1: 75, 2: 85, 3: 4000}; Grads/Draw: {0: [7, 10, 13, 7, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [7, 7, 15, 7, 7]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 4000, 1: 79, 2: 88, 3: 4000}; Grads/Draw: {0: [6, 6, 10, 9, 3], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [7, 7, 15, 7, 7]}; Posterior divergences: {}
# [NutBolt] Aborting sampler (ok_to_abort or max_time reached)...
# [NutBolt] Rejecting completed chain 0: 2222 posterior divergences exceed the allowed 6 (0.200% of 3000 draws).
# Clean complete chains (posterior-only) kept: 1 of 4
# WARNING: compiled_model.shapes is not usable ('builtins.PyVariable' object has no attribute 'dtype'); falling back to empty shapes.
# SHAPES USED: {'offset': (2766,), 'intercept_group': (2766,), 'beta_bin': (10,)}
# [NutBolt] Updated bootstrap init center from finished chains.
# [NutBolt] Saving partial idata to /mnt/d/ISAR Multi-CPTs/Oct 2026/Multiple CPTs/Morbidity_pymc/idata_chunk_1789679543.nc...
# [NutBolt] Accumulated complete chains: 1
#
# [NutBolt] Start nutpie run 2/10: have 1/4 complete chains.
# [NutBolt] Using seed = 133 for this run.
# <style>
#     :root {
#         --column-width-1: 40%; /* Progress column width */
#         --column-width-2: 15%; /* Chain column width */
#         --column-width-3: 15%; /* Divergences column width */
#         --column-width-4: 15%; /* Step Size column width */
#         --column-width-5: 15%; /* Gradients/Draw column width */
#     }
#
#     .nutpie {
#         max-width: 800px;
#         margin: 10px auto;
#         font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#         //color: #333;
#         //background-color: #fff;
#         padding: 10px;
#         box-shadow: 0 4px 6px rgba(0,0,0,0.1);
#         border-radius: 8px;
#         font-size: 14px; /* Smaller font size for a more compact look */
#     }
#     .nutpie table {
#         width: 100%;
#         border-collapse: collapse; /* Remove any extra space between borders */
#     }
#     .nutpie th, .nutpie td {
#         padding: 8px 10px; /* Reduce padding to make table more compact */
#         text-align: left;
#         border-bottom: 1px solid #888;
#     }
#     .nutpie th {
#         //background-color: #f0f0f0;
#     }
#
#     .nutpie th:nth-child(1) { width: var(--column-width-1); }
#     .nutpie th:nth-child(2) { width: var(--column-width-2); }
#     .nutpie th:nth-child(3) { width: var(--column-width-3); }
#     .nutpie th:nth-child(4) { width: var(--column-width-4); }
#     .nutpie th:nth-child(5) { width: var(--column-width-5); }
#
#     .nutpie progress {
#         width: 100%;
#         height: 15px; /* Smaller progress bars */
#         border-radius: 5px;
#     }
#     progress::-webkit-progress-bar {
#         background-color: #eee;
#         border-radius: 5px;
#     }
#     progress::-webkit-progress-value {
#         background-color: #5cb85c;
#         border-radius: 5px;
#     }
#     progress::-moz-progress-bar {
#         background-color: #5cb85c;
#         border-radius: 5px;
#     }
#     .nutpie .progress-cell {
#         width: 100%;
#     }
#
#     .nutpie p strong { font-size: 16px; font-weight: bold; }
#
#     @media (prefers-color-scheme: dark) {
#         .nutpie {
#             //color: #ddd;
#             //background-color: #1e1e1e;
#             box-shadow: 0 4px 6px rgba(0,0,0,0.2);
#         }
#         .nutpie table, .nutpie th, .nutpie td {
#             border-color: #555;
#             color: #ccc;
#         }
#         .nutpie th {
#             background-color: #2a2a2a;
#         }
#         .nutpie progress::-webkit-progress-bar {
#             background-color: #444;
#         }
#         .nutpie progress::-webkit-progress-value {
#             background-color: #3178c6;
#         }
#         .nutpie progress::-moz-progress-bar {
#             background-color: #3178c6;
#         }
#     }
# </style>
# <div class="nutpie">
#     <p><strong>Sampler Progress</strong></p>
#     <p>Total Chains: <span id="total-chains">4</span></p>
#     <p>Active Chains: <span id="active-chains">4</span></p>
#     <p>
#         Finished Chains:
#         <span id="active-chains">0</span>
#     </p>
#     <p>Sampling for 2 minutes</p>
#     <p>
#         Estimated Time to Completion:
#         <span id="eta">5 hours</span>
#     </p>
#
#     <progress
#         id="total-progress-bar"
#         max="16000"
#         value="140">
#     </progress>
#     <table>
#         <thead>
#             <tr>
#                 <th>Progress</th>
#                 <th>Draws</th>
#                 <th>Divergences</th>
#                 <th>Step Size</th>
#                 <th>Gradients/Draw</th>
#             </tr>
#         </thead>
#         <tbody id="chain-details">
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="4000"
#                             value="35">
#                         </progress>
#                     </td>
#                     <td>35</td>
#                     <td>0</td>
#                     <td>0.00</td>
#                     <td>1023</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="4000"
#                             value="43">
#                         </progress>
#                     </td>
#                     <td>43</td>
#                     <td>0</td>
#                     <td>0.00</td>
#                     <td>1023</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="4000"
#                             value="31">
#                         </progress>
#                     </td>
#                     <td>31</td>
#                     <td>0</td>
#                     <td>0.00</td>
#                     <td>1023</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="4000"
#                             value="31">
#                         </progress>
#                     </td>
#                     <td>31</td>
#                     <td>0</td>
#                     <td>0.00</td>
#                     <td>1023</td>
#                 </tr>
#
#             </tr>
#         </tbody>
#     </table>
# </div>
# [NutBolt] Draws: {0: 15, 1: 25, 2: 10, 3: 13}; Grads/Draw: {0: [31, 127, 255, 511, 1023], 1: [255, 255, 127, 255, 255], 2: [2, 113, 127, 255, 1023], 3: [31, 63, 127, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 21, 1: 28, 2: 13, 3: 15}; Grads/Draw: {0: [1023, 127, 15, 63, 127], 1: [255, 255, 1023, 1023, 1023], 2: [255, 1023, 1023, 1023, 1023], 3: [127, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 24, 1: 30, 2: 15, 3: 19}; Grads/Draw: {0: [63, 127, 511, 1023, 1023], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [1023, 1023, 1023, 511, 63]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 26, 1: 32, 2: 21, 3: 22}; Grads/Draw: {0: [511, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 1023, 1023], 2: [255, 15, 63, 127, 511], 3: [511, 63, 511, 511, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 28, 1: 36, 2: 24, 3: 24}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 255, 511], 2: [127, 511, 1023, 1023, 1023], 3: [511, 511, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 31, 1: 39, 2: 26, 3: 27}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [255, 511, 511, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 33, 1: 41, 2: 28, 3: 29}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [511, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 35, 1: 43, 2: 31, 3: 31}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Early abort: Gradients/Draw near saturation (924+) across chains.
# Clean complete chains (posterior-only) kept: 0 of 4
#
# [NutBolt] Start nutpie run 3/10: have 1/4 complete chains.
# [NutBolt] Using seed = 141 for this run.
# <style>
#     :root {
#         --column-width-1: 40%; /* Progress column width */
#         --column-width-2: 15%; /* Chain column width */
#         --column-width-3: 15%; /* Divergences column width */
#         --column-width-4: 15%; /* Step Size column width */
#         --column-width-5: 15%; /* Gradients/Draw column width */
#     }
#
#     .nutpie {
#         max-width: 800px;
#         margin: 10px auto;
#         font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#         //color: #333;
#         //background-color: #fff;
#         padding: 10px;
#         box-shadow: 0 4px 6px rgba(0,0,0,0.1);
#         border-radius: 8px;
#         font-size: 14px; /* Smaller font size for a more compact look */
#     }
#     .nutpie table {
#         width: 100%;
#         border-collapse: collapse; /* Remove any extra space between borders */
#     }
#     .nutpie th, .nutpie td {
#         padding: 8px 10px; /* Reduce padding to make table more compact */
#         text-align: left;
#         border-bottom: 1px solid #888;
#     }
#     .nutpie th {
#         //background-color: #f0f0f0;
#     }
#
#     .nutpie th:nth-child(1) { width: var(--column-width-1); }
#     .nutpie th:nth-child(2) { width: var(--column-width-2); }
#     .nutpie th:nth-child(3) { width: var(--column-width-3); }
#     .nutpie th:nth-child(4) { width: var(--column-width-4); }
#     .nutpie th:nth-child(5) { width: var(--column-width-5); }
#
#     .nutpie progress {
#         width: 100%;
#         height: 15px; /* Smaller progress bars */
#         border-radius: 5px;
#     }
#     progress::-webkit-progress-bar {
#         background-color: #eee;
#         border-radius: 5px;
#     }
#     progress::-webkit-progress-value {
#         background-color: #5cb85c;
#         border-radius: 5px;
#     }
#     progress::-moz-progress-bar {
#         background-color: #5cb85c;
#         border-radius: 5px;
#     }
#     .nutpie .progress-cell {
#         width: 100%;
#     }
#
#     .nutpie p strong { font-size: 16px; font-weight: bold; }
#
#     @media (prefers-color-scheme: dark) {
#         .nutpie {
#             //color: #ddd;
#             //background-color: #1e1e1e;
#             box-shadow: 0 4px 6px rgba(0,0,0,0.2);
#         }
#         .nutpie table, .nutpie th, .nutpie td {
#             border-color: #555;
#             color: #ccc;
#         }
#         .nutpie th {
#             background-color: #2a2a2a;
#         }
#         .nutpie progress::-webkit-progress-bar {
#             background-color: #444;
#         }
#         .nutpie progress::-webkit-progress-value {
#             background-color: #3178c6;
#         }
#         .nutpie progress::-moz-progress-bar {
#             background-color: #3178c6;
#         }
#     }
# </style>
# <div class="nutpie">
#     <p><strong>Sampler Progress</strong></p>
#     <p>Total Chains: <span id="total-chains">4</span></p>
#     <p>Active Chains: <span id="active-chains">2</span></p>
#     <p>
#         Finished Chains:
#         <span id="active-chains">2</span>
#     </p>
#     <p>Sampling for 9 minutes</p>
#     <p>
#         Estimated Time to Completion:
#         <span id="eta">17 minutes</span>
#     </p>
#
#     <progress
#         id="total-progress-bar"
#         max="16000"
#         value="8172">
#     </progress>
#     <table>
#         <thead>
#             <tr>
#                 <th>Progress</th>
#                 <th>Draws</th>
#                 <th>Divergences</th>
#                 <th>Step Size</th>
#                 <th>Gradients/Draw</th>
#             </tr>
#         </thead>
#         <tbody id="chain-details">
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="4000"
#                             value="4000">
#                         </progress>
#                     </td>
#                     <td>4000</td>
#                     <td>0</td>
#                     <td>0.40</td>
#                     <td>15</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="4000"
#                             value="84">
#                         </progress>
#                     </td>
#                     <td>84</td>
#                     <td>0</td>
#                     <td>0.00</td>
#                     <td>1023</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="4000"
#                             value="4000">
#                         </progress>
#                     </td>
#                     <td>4000</td>
#                     <td>0</td>
#                     <td>0.41</td>
#                     <td>15</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="4000"
#                             value="88">
#                         </progress>
#                     </td>
#                     <td>88</td>
#                     <td>0</td>
#                     <td>0.00</td>
#                     <td>1023</td>
#                 </tr>
#
#             </tr>
#         </tbody>
#     </table>
# </div>
# [NutBolt] Draws: {0: 3, 1: 10, 2: 9, 3: 11}; Grads/Draw: {0: [1023, 127, 255], 1: [127, 63, 255, 511, 1023], 2: [15, 63, 127, 511, 1023], 3: [31, 127, 127, 511, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 6, 1: 12, 2: 11, 3: 13}; Grads/Draw: {0: [127, 255, 1023, 1023, 1023], 1: [255, 511, 1023, 1023, 1023], 2: [127, 511, 1023, 1023, 1023], 3: [127, 511, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 8, 1: 16, 2: 138, 3: 20}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 1023, 7], 2: [7, 15, 15, 3, 7], 3: [127, 31, 63, 255, 511]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 109, 1: 18, 2: 341, 3: 22}; Grads/Draw: {0: [15, 7, 15, 15, 3], 1: [1023, 1023, 7, 1023, 1023], 2: [15, 7, 7, 15, 15], 3: [63, 255, 511, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 334, 1: 21, 2: 487, 3: 25}; Grads/Draw: {0: [15, 7, 7, 4, 6], 1: [1023, 1023, 1023, 1023, 1023], 2: [6, 15, 3, 7, 15], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 534, 1: 23, 2: 621, 3: 27}; Grads/Draw: {0: [7, 15, 7, 15, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [7, 15, 7, 7, 15], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 650, 1: 26, 2: 748, 3: 30}; Grads/Draw: {0: [7, 7, 15, 15, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [7, 7, 15, 15, 7], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 750, 1: 30, 2: 853, 3: 34}; Grads/Draw: {0: [15, 4, 15, 15, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [15, 15, 15, 15, 15], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 810, 1: 32, 2: 1095, 3: 37}; Grads/Draw: {0: [15, 7, 15, 7, 7], 1: [1023, 1023, 1023, 1023, 1023], 2: [7, 15, 7, 7, 7], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 966, 1: 35, 2: 1295, 3: 39}; Grads/Draw: {0: [15, 15, 15, 15, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [15, 15, 15, 15, 15], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 1121, 1: 37, 2: 1503, 3: 42}; Grads/Draw: {0: [15, 15, 7, 15, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [7, 7, 15, 15, 15], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 1274, 1: 40, 2: 1704, 3: 44}; Grads/Draw: {0: [15, 15, 7, 15, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [7, 15, 15, 7, 15], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 1430, 1: 42, 2: 1910, 3: 47}; Grads/Draw: {0: [15, 7, 15, 15, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [7, 7, 7, 15, 15], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 1590, 1: 45, 2: 2114, 3: 49}; Grads/Draw: {0: [15, 15, 15, 15, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [15, 7, 7, 7, 15], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 1750, 1: 47, 2: 2315, 3: 52}; Grads/Draw: {0: [15, 7, 15, 15, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [7, 15, 7, 7, 15], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 1909, 1: 50, 2: 2510, 3: 54}; Grads/Draw: {0: [15, 15, 15, 15, 7], 1: [1023, 1023, 1023, 1023, 1023], 2: [15, 15, 15, 15, 7], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 2065, 1: 53, 2: 2718, 3: 57}; Grads/Draw: {0: [15, 15, 15, 15, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [7, 15, 7, 15, 15], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 2224, 1: 55, 2: 2922, 3: 59}; Grads/Draw: {0: [15, 15, 15, 15, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [7, 15, 7, 7, 7], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 2384, 1: 58, 2: 3138, 3: 62}; Grads/Draw: {0: [15, 15, 15, 15, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [15, 15, 7, 15, 7], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 2541, 1: 60, 2: 3342, 3: 64}; Grads/Draw: {0: [15, 15, 15, 15, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [15, 7, 7, 15, 7], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 2701, 1: 63, 2: 3551, 3: 67}; Grads/Draw: {0: [15, 15, 15, 15, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [7, 7, 15, 7, 15], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 2861, 1: 65, 2: 3752, 3: 70}; Grads/Draw: {0: [15, 15, 15, 15, 7], 1: [1023, 1023, 1023, 1023, 1023], 2: [15, 15, 7, 7, 15], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 3023, 1: 68, 2: 3957, 3: 72}; Grads/Draw: {0: [15, 15, 15, 15, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [7, 15, 15, 7, 15], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 3220, 1: 71, 2: 4000, 3: 75}; Grads/Draw: {0: [15, 15, 15, 15, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [7, 7, 7, 15, 15], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 3424, 1: 74, 2: 4000, 3: 78}; Grads/Draw: {0: [15, 15, 15, 15, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [7, 7, 7, 15, 15], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 3624, 1: 77, 2: 4000, 3: 82}; Grads/Draw: {0: [7, 15, 15, 15, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [7, 7, 7, 15, 15], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 3825, 1: 80, 2: 4000, 3: 85}; Grads/Draw: {0: [15, 15, 15, 15, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [7, 7, 7, 15, 15], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 4000, 1: 84, 2: 4000, 3: 88}; Grads/Draw: {0: [15, 15, 15, 15, 15], 1: [1023, 1023, 1023, 1023, 1023], 2: [7, 7, 7, 15, 15], 3: [1023, 1023, 1023, 1023, 1023]}; Posterior divergences: {}
# [NutBolt] Aborting sampler (ok_to_abort or max_time reached)...
# Clean complete chains (posterior-only) kept: 2 of 4
# WARNING: compiled_model.shapes is not usable ('builtins.PyVariable' object has no attribute 'dtype'); falling back to empty shapes.
# SHAPES USED: {'offset': (2766,), 'intercept_group': (2766,), 'beta_bin': (10,)}
# [NutBolt] Updated bootstrap init center from finished chains.
# [NutBolt] Saving partial idata to /mnt/d/ISAR Multi-CPTs/Oct 2026/Multiple CPTs/Morbidity_pymc/idata_chunk_1789680279.nc...
# [NutBolt] Accumulated complete chains: 3
#
# [NutBolt] Start nutpie run 4/10: have 3/4 complete chains.
# [NutBolt] Using seed = 151 for this run.
# <style>
#     :root {
#         --column-width-1: 40%; /* Progress column width */
#         --column-width-2: 15%; /* Chain column width */
#         --column-width-3: 15%; /* Divergences column width */
#         --column-width-4: 15%; /* Step Size column width */
#         --column-width-5: 15%; /* Gradients/Draw column width */
#     }
#
#     .nutpie {
#         max-width: 800px;
#         margin: 10px auto;
#         font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#         //color: #333;
#         //background-color: #fff;
#         padding: 10px;
#         box-shadow: 0 4px 6px rgba(0,0,0,0.1);
#         border-radius: 8px;
#         font-size: 14px; /* Smaller font size for a more compact look */
#     }
#     .nutpie table {
#         width: 100%;
#         border-collapse: collapse; /* Remove any extra space between borders */
#     }
#     .nutpie th, .nutpie td {
#         padding: 8px 10px; /* Reduce padding to make table more compact */
#         text-align: left;
#         border-bottom: 1px solid #888;
#     }
#     .nutpie th {
#         //background-color: #f0f0f0;
#     }
#
#     .nutpie th:nth-child(1) { width: var(--column-width-1); }
#     .nutpie th:nth-child(2) { width: var(--column-width-2); }
#     .nutpie th:nth-child(3) { width: var(--column-width-3); }
#     .nutpie th:nth-child(4) { width: var(--column-width-4); }
#     .nutpie th:nth-child(5) { width: var(--column-width-5); }
#
#     .nutpie progress {
#         width: 100%;
#         height: 15px; /* Smaller progress bars */
#         border-radius: 5px;
#     }
#     progress::-webkit-progress-bar {
#         background-color: #eee;
#         border-radius: 5px;
#     }
#     progress::-webkit-progress-value {
#         background-color: #5cb85c;
#         border-radius: 5px;
#     }
#     progress::-moz-progress-bar {
#         background-color: #5cb85c;
#         border-radius: 5px;
#     }
#     .nutpie .progress-cell {
#         width: 100%;
#     }
#
#     .nutpie p strong { font-size: 16px; font-weight: bold; }
#
#     @media (prefers-color-scheme: dark) {
#         .nutpie {
#             //color: #ddd;
#             //background-color: #1e1e1e;
#             box-shadow: 0 4px 6px rgba(0,0,0,0.2);
#         }
#         .nutpie table, .nutpie th, .nutpie td {
#             border-color: #555;
#             color: #ccc;
#         }
#         .nutpie th {
#             background-color: #2a2a2a;
#         }
#         .nutpie progress::-webkit-progress-bar {
#             background-color: #444;
#         }
#         .nutpie progress::-webkit-progress-value {
#             background-color: #3178c6;
#         }
#         .nutpie progress::-moz-progress-bar {
#             background-color: #3178c6;
#         }
#     }
# </style>
# <div class="nutpie">
#     <p><strong>Sampler Progress</strong></p>
#     <p>Total Chains: <span id="total-chains">4</span></p>
#     <p>Active Chains: <span id="active-chains">3</span></p>
#     <p>
#         Finished Chains:
#         <span id="active-chains">1</span>
#     </p>
#     <p>Sampling for 7 minutes</p>
#     <p>
#         Estimated Time to Completion:
#         <span id="eta">28 minutes</span>
#     </p>
#
#     <progress
#         id="total-progress-bar"
#         max="16000"
#         value="4204">
#     </progress>
#     <table>
#         <thead>
#             <tr>
#                 <th>Progress</th>
#                 <th>Draws</th>
#                 <th>Divergences</th>
#                 <th>Step Size</th>
#                 <th>Gradients/Draw</th>
#             </tr>
#         </thead>
#         <tbody id="chain-details">
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="4000"
#                             value="69">
#                         </progress>
#                     </td>
#                     <td>69</td>
#                     <td>0</td>
#                     <td>0.00</td>
#                     <td>1023</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="4000"
#                             value="67">
#                         </progress>
#                     </td>
#                     <td>67</td>
#                     <td>0</td>
#                     <td>0.00</td>
#                     <td>1023</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="4000"
#                             value="68">
#                         </progress>
#                     </td>
#                     <td>68</td>
#                     <td>0</td>
#                     <td>0.00</td>
#                     <td>1023</td>
#                 </tr>
#
#                 <tr>
#                     <td class="progress-cell">
#                         <progress
#                             max="4000"
#                             value="4000">
#                         </progress>
#                     </td>
#                     <td>4000</td>
#                     <td>0</td>
#                     <td>0.46</td>
#                     <td>15</td>
#                 </tr>
#
#             </tr>
#         </tbody>
#     </table>
# </div>
# [NutBolt] Draws: {0: 13, 1: 8, 2: 12, 3: 207}; Grads/Draw: {0: [31, 63, 511, 511, 1023], 1: [63, 63, 127, 1023, 1023], 2: [31, 63, 511, 511, 1023], 3: [7, 15, 4, 15, 7]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 15, 1: 10, 2: 14, 3: 399}; Grads/Draw: {0: [511, 511, 1023, 1023, 1023], 1: [127, 1023, 1023, 1023, 1023], 2: [511, 511, 1023, 1023, 1023], 3: [7, 15, 15, 15, 5]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 19, 1: 17, 2: 18, 3: 511}; Grads/Draw: {0: [1023, 1023, 3, 1023, 1023], 1: [255, 127, 127, 255, 511], 2: [1023, 1023, 1023, 3, 1023], 3: [7, 15, 5, 7, 15]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 22, 1: 19, 2: 21, 3: 616}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [127, 255, 511, 1023, 1023], 2: [3, 1023, 1023, 1023, 1023], 3: [15, 15, 15, 15, 15]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 24, 1: 22, 2: 24, 3: 716}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [7, 7, 7, 15, 15]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 27, 1: 25, 2: 26, 3: 816}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [15, 15, 15, 7, 15]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 30, 1: 27, 2: 29, 3: 973}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [15, 15, 15, 7, 7]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 32, 1: 30, 2: 31, 3: 1166}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [7, 15, 7, 7, 15]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 34, 1: 32, 2: 33, 3: 1348}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [15, 15, 7, 15, 15]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 37, 1: 34, 2: 36, 3: 1540}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [15, 15, 7, 15, 7]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 39, 1: 37, 2: 38, 3: 1734}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [7, 7, 15, 7, 15]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 42, 1: 39, 2: 41, 3: 1924}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [7, 15, 15, 15, 15]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 44, 1: 42, 2: 43, 3: 2107}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [7, 7, 15, 15, 15]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 47, 1: 44, 2: 46, 3: 2299}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [15, 15, 15, 15, 15]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 49, 1: 47, 2: 48, 3: 2495}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [15, 15, 7, 15, 7]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 51, 1: 49, 2: 51, 3: 2690}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [7, 7, 7, 15, 7]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 54, 1: 52, 2: 53, 3: 2893}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [7, 7, 15, 7, 7]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 56, 1: 54, 2: 55, 3: 3081}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [15, 7, 7, 15, 15]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 59, 1: 57, 2: 58, 3: 3280}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [7, 15, 15, 7, 7]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 61, 1: 59, 2: 60, 3: 3477}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [7, 7, 7, 15, 15]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 64, 1: 62, 2: 63, 3: 3674}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [7, 15, 15, 15, 7]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 66, 1: 64, 2: 65, 3: 3875}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [15, 7, 7, 7, 15]}; Posterior divergences: {}
# [NutBolt] Draws: {0: 69, 1: 67, 2: 68, 3: 4000}; Grads/Draw: {0: [1023, 1023, 1023, 1023, 1023], 1: [1023, 1023, 1023, 1023, 1023], 2: [1023, 1023, 1023, 1023, 1023], 3: [15, 7, 15, 7, 15]}; Posterior divergences: {}
# [NutBolt] Aborting sampler (ok_to_abort or max_time reached)...
# Clean complete chains (posterior-only) kept: 1 of 4
# WARNING: compiled_model.shapes is not usable ('builtins.PyVariable' object has no attribute 'dtype'); falling back to empty shapes.
# SHAPES USED: {'offset': (2766,), 'intercept_group': (2766,), 'beta_bin': (10,)}
# [NutBolt] Updated bootstrap init center from finished chains.
# [NutBolt] Saving partial idata to /mnt/d/ISAR Multi-CPTs/Oct 2026/Multiple CPTs/Morbidity_pymc/idata_chunk_1789680749.nc...
# [NutBolt] Accumulated complete chains: 4
# [NutBolt] Total inference time: 0:29:16
# first batch shapes: Xb (10000, 10) di_b (10000,) mean_noblup (10000,) n_clusters 2766
# [NutBolt] Diagnostics: 0 divergences out of 12000 draws.
# Random Intercept Variance Summary:
#          index     mean        sd  hdi_lower  hdi_upper     ess_bulk  \
# 0  signal_var  0.68468  0.025464   0.635739    0.73557  1039.786501
#
#       ess_tail     r_hat  mcse_mean   mcse_sd
# 0  1264.662678  1.002393   0.000797  0.000555
#
#
#                                                    mean      sd  hdi_lower  \
# signal_var                                       0.6847  0.0255     0.6357
# beta0                                           -3.4182  0.0241    -3.4650
# beta_bin[agegroup_bucket __ 2-45-64]             0.0782  0.0063     0.0661
# beta_bin[agegroup_bucket __ 3-65-74]             0.1356  0.0070     0.1219
# beta_bin[agegroup_bucket __ 4-75-84]             0.2592  0.0076     0.2442
# beta_bin[agegroup_bucket __ 5->=85]              0.3383  0.0107     0.3179
# beta_bin[asaclas __ 2-Mild Disturb]              0.3090  0.0139     0.2825
# beta_bin[asaclas __ 3-Severe Disturb]            0.7788  0.0140     0.7513
# beta_bin[asaclas __ 4-Life Threat]               1.3623  0.0148     1.3336
# beta_bin[asaclas __ 5-Moribund]                  2.0202  0.0251     1.9705
# beta_bin[fnstatpressurg __ Partially Dependent]  0.4949  0.0097     0.4752
# beta_bin[fnstatpressurg __ Totally Dependent]    0.5569  0.0202     0.5159
#
#                                                  hdi_upper   ess_bulk  \
# signal_var                                          0.7356  1039.7865
# beta0                                              -3.3723  3012.3372
# beta_bin[agegroup_bucket __ 2-45-64]                0.0911  2647.4639
# beta_bin[agegroup_bucket __ 3-65-74]                0.1494  2539.5825
# beta_bin[agegroup_bucket __ 4-75-84]                0.2734  2777.4493
# beta_bin[agegroup_bucket __ 5->=85]                 0.3598  3333.8702
# beta_bin[asaclas __ 2-Mild Disturb]                 0.3361  3360.1515
# beta_bin[asaclas __ 3-Severe Disturb]               0.8061  3460.9654
# beta_bin[asaclas __ 4-Life Threat]                  1.3911  3499.1304
# beta_bin[asaclas __ 5-Moribund]                     2.0691  4918.3422
# beta_bin[fnstatpressurg __ Partially Dependent]     0.5132  5306.9340
# beta_bin[fnstatpressurg __ Totally Dependent]       0.5961  6783.4629
#
#                                                   ess_tail   r_hat  mcse_mean  \
# signal_var                                       1264.6627  1.0024     0.0008
# beta0                                            3337.0333  1.0011     0.0004
# beta_bin[agegroup_bucket __ 2-45-64]             3059.5226  1.0014     0.0001
# beta_bin[agegroup_bucket __ 3-65-74]             3072.5762  1.0029     0.0001
# beta_bin[agegroup_bucket __ 4-75-84]             3569.6462  1.0025     0.0001
# beta_bin[agegroup_bucket __ 5->=85]              3279.3505  1.0010     0.0002
# beta_bin[asaclas __ 2-Mild Disturb]              3702.1805  1.0002     0.0002
# beta_bin[asaclas __ 3-Severe Disturb]            3769.3335  1.0002     0.0002
# beta_bin[asaclas __ 4-Life Threat]               3878.9585  1.0005     0.0003
# beta_bin[asaclas __ 5-Moribund]                  4223.3628  1.0012     0.0004
# beta_bin[fnstatpressurg __ Partially Dependent]  3903.4358  1.0001     0.0001
# beta_bin[fnstatpressurg __ Totally Dependent]    3775.9979  1.0029     0.0002
#
#                                                  mcse_sd
# signal_var                                        0.0006
# beta0                                             0.0003
# beta_bin[agegroup_bucket __ 2-45-64]              0.0001
# beta_bin[agegroup_bucket __ 3-65-74]              0.0001
# beta_bin[agegroup_bucket __ 4-75-84]              0.0001
# beta_bin[agegroup_bucket __ 5->=85]               0.0001
# beta_bin[asaclas __ 2-Mild Disturb]               0.0002
# beta_bin[asaclas __ 3-Severe Disturb]             0.0002
# beta_bin[asaclas __ 4-Life Threat]                0.0002
# beta_bin[asaclas __ 5-Moribund]                   0.0003
# beta_bin[fnstatpressurg __ Partially Dependent]   0.0001
# beta_bin[fnstatpressurg __ Totally Dependent]     0.0002
#
# ****************************************
#
# Divergences: 0
# Min ESS: 1039.8
# Max R-hat: 1.006
# Min EBFMI: 0.683

# %% [markdown]
# ## EGS Sermorb CPT linear risk

# %%
# model_name="EGS_sermorb_pymc"
# print(f"\n{"*"*40}\n{model_name}\n{"*"*40}\n")
# sar_cptlin_runner.run_model(
#     outcome="sermorb",
#     model_name=model_name,
#     cluster_var="prncptx",
#     df=df.copy(),
#     predictors = ["agegroup_bucket", "asaclas", "fnstatpressurg"],
#     target_accept=0.3,
#     chains_per_run=4,
#     n_total_chains=4,
#     low_rank_modified_mass_matrix=True,
#     mass_matrix_eigval_cutoff=20,
#     mass_matrix_gamma =1e-2,
#     tune=1000,
#     draws=4000,
#     tolerance=1000,
#     check_every_s=20,
#     max_time_s=3600, 
#     seed=123,
#     output_folder=output_folder)

# %%
# sar_cptlin_runner.export_current_notebook_to_html(master_folder, 
#                                 output_name="CPTlin_Jul2026", 
#                                 add_timestamp=True)
